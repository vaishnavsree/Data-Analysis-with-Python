# %%
#Importing Libraries

import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Task1: Merge 12 months of data into single csv file

# %%
files = [file for file in os.listdir('D:\\Data Analytics\\Data Analysis with Python\\Sales_Data\\Dataset')]

final_dataset = pd.DataFrame()

for file in files:
    df = pd.read_csv("./Dataset/{}".format(file))
    final_dataset = pd.concat([final_dataset,df])

final_dataset
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# 0      04/19/19 08:46             917 1st St, Dallas, TX 75001
# 1                 NaN                                      NaN
# 2      04/07/19 22:30        682 Chestnut St, Boston, MA 02215
# 3      04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# 4      04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001
# ...               ...                                      ...
# 11681  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 11682  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 11683  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 11684  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 11685  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016
#
# [186850 rows x 6 columns]

# %%
final_dataset.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186850 entries, 0 to 11685
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 5.7+ MB

# %%
final_dataset.dropna(axis=0,inplace=True)

# %% [markdown]
# # What was the best month for sales? How much was earned that month?

# %%
# Extracting month value from order date

final_dataset['Month'] = final_dataset['Order Date'].str[:2]

# %%
final_dataset = final_dataset[final_dataset['Month'] != 'Or']
final_dataset.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04

# %%
final_dataset['Quantity Ordered'] = pd.to_numeric(final_dataset['Quantity Ordered'])

final_dataset['Price Each'] = pd.to_numeric(final_dataset['Price Each'])
# Out:
# <ipython-input-8-f197cc85f2ca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset['Quantity Ordered'] = pd.to_numeric(final_dataset['Quantity Ordered'])
# <ipython-input-8-f197cc85f2ca>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset['Price Each'] = pd.to_numeric(final_dataset['Price Each'])

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 11685
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 7.8+ MB

# %%
final_dataset['Sales Value'] = final_dataset['Quantity Ordered'] * final_dataset['Price Each']

final_dataset.head()
# Out:
# <ipython-input-10-eafe4c5f0ec8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset['Sales Value'] = final_dataset['Quantity Ordered'] * final_dataset['Price Each']
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month  Sales Value
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04        23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04        99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04       600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04        11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04        11.99

# %%
results = final_dataset.groupby('Month').sum()
results
# Out:
#        Quantity Ordered    Price Each   Sales Value
# Month
# 01                10903  1.811768e+06  1.822257e+06
# 02                13449  2.188885e+06  2.202022e+06
# 03                17005  2.791208e+06  2.807100e+06
# 04                20558  3.367671e+06  3.390670e+06
# 05                18667  3.135125e+06  3.152607e+06
# 06                15253  2.562026e+06  2.577802e+06
# 07                16072  2.632540e+06  2.647776e+06
# 08                13448  2.230345e+06  2.244468e+06
# 09                13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
plt.figure(figsize=(15,8))

plt.bar(results.index,results['Sales Value'])
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# # Which city had the highest number of sales?

# %%
final_dataset['City'] = final_dataset['Purchase Address'].apply(lambda x : x.split(",")[1] + ' '+ x.split(",")[2][:3])

final_dataset.head()
# Out:
# <ipython-input-13-eb35a7855a50>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset['City'] = final_dataset['Purchase Address'].apply(lambda x : x.split(",")[1] + ' '+ x.split(",")[2][:3])
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address Month  Sales Value  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    04        23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    04        99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04       600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    04        11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    04        11.99
#
#                City
# 0        Dallas  TX
# 2        Boston  MA
# 3   Los Angeles  CA
# 4   Los Angeles  CA
# 5   Los Angeles  CA

# %%
city_with_highest_sales = final_dataset.groupby('City').sum()
city_with_highest_sales.sort_values(by='Sales Value',ascending=False)
# Out:
#                     Quantity Ordered    Price Each   Sales Value
# City
#  San Francisco  CA             50239  8.211462e+06  8.262204e+06
#  Los Angeles  CA               33289  5.421435e+06  5.452571e+06
#  New York City  NY             27932  4.635371e+06  4.664317e+06
#  Boston  MA                    22528  3.637410e+06  3.661642e+06
#  Atlanta  GA                   16602  2.779908e+06  2.795499e+06
#  Dallas  TX                    16730  2.752628e+06  2.767975e+06
#  Seattle  WA                   16553  2.733296e+06  2.747755e+06
#  Portland  OR                  11303  1.860558e+06  1.870732e+06
#  Austin  TX                    11153  1.809874e+06  1.819582e+06
#  Portland  ME                   2750  4.471893e+05  4.497583e+05

# %%
sns.barplot(y=city_with_highest_sales.index,x=city_with_highest_sales['Sales Value'])
# Out:
# <AxesSubplot:xlabel='Sales Value', ylabel='City'>

# %% [markdown]
# # What time should we display Ads to maximize the likelihood of customers buying products?

# %%
import datetime

# %%
final_dataset['Order Date'] = pd.to_datetime(final_dataset['Order Date'])
# Out:
# <ipython-input-17-f8f9fc3a47f6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset['Order Date'] = pd.to_datetime(final_dataset['Order Date'])

# %%
final_dataset.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    04
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    04
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    04
#
#    Sales Value              City
# 0        23.90        Dallas  TX
# 2        99.99        Boston  MA
# 3       600.00   Los Angeles  CA
# 4        11.99   Los Angeles  CA
# 5        11.99   Los Angeles  CA

# %%
final_dataset["Hour"] = final_dataset['Order Date'].dt.hour
final_dataset["Minute"] = final_dataset['Order Date'].dt.minute

final_dataset.head()
# Out:
# <ipython-input-19-fa5f600994a0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset["Hour"] = final_dataset['Order Date'].dt.hour
# <ipython-input-19-fa5f600994a0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset["Minute"] = final_dataset['Order Date'].dt.minute
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    04
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    04
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    04
#
#    Sales Value              City  Hour  Minute
# 0        23.90        Dallas  TX     8      46
# 2        99.99        Boston  MA    22      30
# 3       600.00   Los Angeles  CA    14      38
# 4        11.99   Los Angeles  CA    14      38
# 5        11.99   Los Angeles  CA     9      27

# %%
sns.histplot(x=final_dataset['Hour'],kde=True)
plt.grid()

# %% [markdown]
# # Which products are sold together

# %%
final_dataset.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    04
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    04
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    04
#
#    Sales Value              City  Hour  Minute
# 0        23.90        Dallas  TX     8      46
# 2        99.99        Boston  MA    22      30
# 3       600.00   Los Angeles  CA    14      38
# 4        11.99   Los Angeles  CA    14      38
# 5        11.99   Los Angeles  CA     9      27

# %%
multiple_products_in_single_order_dataset = final_dataset[final_dataset['Order ID'].duplicated(keep=False)]


multiple_products_in_single_order_dataset.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 18   176574                Google Phone                 1      600.00
# 19   176574        USB-C Charging Cable                 1       11.95
# 30   176585  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                      Purchase Address Month  \
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 4  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 18 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001    04
# 19 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001    04
# 30 2019-04-07 11:31:00     823 Highland St, Boston, MA 02215    04
#
#     Sales Value              City  Hour  Minute
# 3        600.00   Los Angeles  CA    14      38
# 4         11.99   Los Angeles  CA    14      38
# 18       600.00   Los Angeles  CA    19      42
# 19        11.95   Los Angeles  CA    19      42
# 30        99.99        Boston  MA    11      31

# %%
multiple_products_in_single_order_dataset['Grouped']  = multiple_products_in_single_order_dataset.groupby('Order ID')['Product'].transform(lambda x: ",".join(x))

multiple_products_in_single_order_dataset.head()
# Out:
# <ipython-input-34-b40ea0e660f9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multiple_products_in_single_order_dataset['Grouped']  = multiple_products_in_single_order_dataset.groupby('Order ID')['Product'].transform(lambda x: ",".join(x))
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 18   176574                Google Phone                 1      600.00
# 19   176574        USB-C Charging Cable                 1       11.95
# 30   176585  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                      Purchase Address Month  \
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 4  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 18 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001    04
# 19 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001    04
# 30 2019-04-07 11:31:00     823 Highland St, Boston, MA 02215    04
#
#     Sales Value              City  Hour  Minute  \
# 3        600.00   Los Angeles  CA    14      38
# 4         11.99   Los Angeles  CA    14      38
# 18       600.00   Los Angeles  CA    19      42
# 19        11.95   Los Angeles  CA    19      42
# 30        99.99        Boston  MA    11      31
#
#                                               Grouped
# 3                       Google Phone,Wired Headphones
# 4                       Google Phone,Wired Headphones
# 18                  Google Phone,USB-C Charging Cable
# 19                  Google Phone,USB-C Charging Cable
# 30  Bose SoundSport Headphones,Bose SoundSport Hea...

# %%
multiple_products_in_single_order_dataset.head()
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 18   176574                Google Phone                 1      600.00
# 19   176574        USB-C Charging Cable                 1       11.95
# 30   176585  Bose SoundSport Headphones                 1       99.99
#
#             Order Date                      Purchase Address Month  \
# 3  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 4  2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    04
# 18 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001    04
# 19 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001    04
# 30 2019-04-07 11:31:00     823 Highland St, Boston, MA 02215    04
#
#     Sales Value              City  Hour  Minute  \
# 3        600.00   Los Angeles  CA    14      38
# 4         11.99   Los Angeles  CA    14      38
# 18       600.00   Los Angeles  CA    19      42
# 19        11.95   Los Angeles  CA    19      42
# 30        99.99        Boston  MA    11      31
#
#                                               Grouped
# 3                       Google Phone,Wired Headphones
# 4                       Google Phone,Wired Headphones
# 18                  Google Phone,USB-C Charging Cable
# 19                  Google Phone,USB-C Charging Cable
# 30  Bose SoundSport Headphones,Bose SoundSport Hea...

# %%
multiple_products_in_single_order_dataset = multiple_products_in_single_order_dataset[['Order ID','Grouped']].drop_duplicates()

multiple_products_in_single_order_dataset.head()
# Out:
#     Order ID                                            Grouped
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in multiple_products_in_single_order_dataset['Grouped']:
    row_list = row.split(",")
    count.update(Counter(combinations(row_list,2)))
    
count.most_common(10)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 160),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %% [markdown]
# # Which product sold the most

# %%
products_sold_most = final_dataset.groupby('Product').sum().sort_values(by='Quantity Ordered',ascending=False)['Quantity Ordered']

products_sold_most = products_sold_most.to_frame()

# %%
products_sold_most.head()
# Out:
#                           Quantity Ordered
# Product
# AAA Batteries (4-pack)               31017
# AA Batteries (4-pack)                27635
# USB-C Charging Cable                 23975
# Lightning Charging Cable             23217
# Wired Headphones                     20557

# %%
plt.figure(figsize=(25,15))

sns.barplot(data=products_sold_most,y=products_sold_most.index,x='Quantity Ordered')
# Out:
# <AxesSubplot:xlabel='Quantity Ordered', ylabel='Product'>
